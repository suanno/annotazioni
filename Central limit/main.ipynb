# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Verifica TCL per r.v. non identicamente distribuite
# - Definisco N r.v. uniformemente distribuited with DIFFERENT centers and widths
# - Per ogni r.v. genero M realizzazioni e faccio la media fra le realizzazioni delle diverse r.v.
#
# Così ottengo M medie, che posso plottare.

# %%
N = int(1e2)
M = int(1e4)
# Generate center and width of the N uniform distributions
w = np.random.randint(1,10,N)
c = np.random.randint(-3,4,N)

# Generate M realizations of each of the N r.v.s
means = np.zeros(M)
for i in range(0,M):
    means[i] = np.mean(np.random.rand(N)*w + c)

plt.hist(means,bins=100);
